# %%
import pandas as pd
import os

list1 = os.listdir(r'C:\Users\Student\Desktop\新增資料夾')
list1
# Out:
# ['一般_2001_2012.csv',
#  '一般_2013_2020.csv',
#  '保險_2001_2012.csv',
#  '保險_2013_2020.csv',
#  '證券_2001_2012.csv',
#  '證券_2013_2020.csv',
#  '金控_2001_2020.csv',
#  '銀行_2001_2012.csv',
#  '銀行_2013_2020.csv']

# %%
for j in list1:
    df = pd.read_csv(rf'C:\Users\Student\Desktop\新增資料夾\{j}',encoding='cp950',index_col=False)
    df = df.groupby(["季別"])
    lists=[]
    for i in df:
        lists.append(i)
    a = lists[3]
    b = list(a)
#     print(b[1])
    print(i)
    b[1].to_csv(rf"C:\Users\Student\Desktop\abc\{j}",index=False)
# Out:
# (4,          公司           簡稱     年   月  季別        營業收入淨額          營業成本  \
# 779    1101  台泥           2001  12   4      20244735      19819285
# 780    1102  亞泥           2001  12   4       9958340       9346545
# 781    1103  嘉泥           2001  12   4       2291102       1969864
# 782    1104  環泥           2001  12   4       2309570       2192078
# 783    1108  幸福           2001  12   4       2354732       2485504
# ...     ...          ...   ...  ..  ..           ...           ...
# 56522  9949  琉園           2012  12   4        347044         99681
# 56523  9950   萬國通         2012  12   4       2995612       2631429
# 56524  9951  皇田           2012  12   4       1678368       1036441
# 56525  9960   邁達康         2012  12   4        442728        322900
# 56526  9962  有益           2012  12   4       4286877       4227611
#
#                營業毛利 聯屬公司已（未）實現銷貨利益       已實現銷貨毛利  ...    其他綜合損益－OCI  \
# 779          425450           1228        426678  ...
# ...

# %%
os.listdir(r'C:\Users\Student\Desktop\abc')
# Out:
# []
