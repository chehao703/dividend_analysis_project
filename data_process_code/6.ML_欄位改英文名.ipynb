# %%
# 改名

import pandas as pd
import os

folder_list = os.listdir(r'C:\Users\Student\Desktop\ML_欄位')
folder_list
# Out:
# ['一般_2001_2020.csv',
#  '保險_2001_2020.csv',
#  '證券_2001_2020.csv',
#  '金控_2001_2020.csv',
#  '銀行_2001_2020.csv']

# %%
dict_column_name = {'公司代碼': 'company_id',
 '公司簡稱': 'company_name',
 '年': 'year',
 '稅前淨利': 'pre_tax_income',
 '所得稅費用': 'income_tax_expense',
 '繼續營業單位損益': 'cont_oper_IL',
 '停業單位損益': 'discont_oper_IL',
 '合併總損益': 'profit',
 '其他綜合損益－OCI': 'other_comprehensive_income',
 '本期綜合損益總額': 'total_comprehensive_income',
 '歸屬母公司淨利（損）': 'parent_PL',
 '歸屬共同控制下前手權益淨利（損）': 'jointly_control_PL',
 '歸屬非控制權益淨利（損）': 'non_control_PL',
 '綜合損益歸屬母公司': 'parent_comprehensive_income',
 '綜合損益歸屬共同控制下前手權益': 'control_comprehensive_income',
 '綜合損益歸屬非控制權益': 'non_control_comprehensive_income',
 '每股盈餘': 'earning_per_share',
 '資產總額': 'total_assets',
 '負債總額': 'total_liabilities',
 '股本': 'stocks',
 '資本公積合計': 'capital_reserve',
 '保留盈餘': 'retained_earnings',
 '其他權益': 'other_equity_interest',
 '庫藏股票帳面值': 'treasury_stock',
 '母公司股東權益合計': 'parent_equity',
 '共同控制下前手權益': 'control_interest',
 '非控制權益': 'non_control_interest',
 '股東權益總額': 'total_equity',
 '預收股款': 'proceeds_issued',
 '庫藏股數（母持及子持母）': 'total_treasury_shares',
 '每股淨值(F)－TSE公告數': 'book_value_per_share',
 '累計_現金股利(元)': 'cash_dividend',
 '盈餘配股(元)': 'stock_dividend',
 '股利市值': 'dividend_value'}

# %%
column_list = list(dict_column_name.values())
print(column_list)
# Out:
# ['company_id', 'company_name', 'year', 'pre_tax_income', 'income_tax_expense', 'cont_oper_IL', 'discont_oper_IL', 'profit', 'other_comprehensive_income', 'total_comprehensive_income', 'parent_PL', 'jointly_control_PL', 'non_control_PL', 'parent_comprehensive_income', 'control_comprehensive_income', 'non_control_comprehensive_income', 'earning_per_share', 'total_assets', 'total_liabilities', 'stocks', 'capital_reserve', 'retained_earnings', 'other_equity_interest', 'treasury_stock', 'parent_equity', 'control_interest', 'non_control_interest', 'total_equity', 'proceeds_issued', 'total_treasury_shares', 'book_value_per_share', 'cash_dividend', 'stock_dividend', 'dividend_value']

# %%
for i in folder_list:
    df = pd.read_csv(rf'C:\Users\Student\Desktop\ML_欄位\{i}',index_col=False)
    df.columns = column_list
    print(df)    
#     print(df.columns)
    df.to_csv(rf'C:\Users\Student\Desktop\ML_欄位_英文\{i}', index=False)
# Out:
#        company_id company_name  year  pre_tax_income  income_tax_expense  \
# 0            1101           台泥  2001        223575.0             33000.0
# 1            1101           台泥  2002        316737.0             30000.0
# 2            1101           台泥  2003       2232182.0            470000.0
# 3            1101           台泥  2004       4653526.0            232000.0
# 4            1101           台泥  2005       6085844.0            309549.0
# ...           ...          ...   ...             ...                 ...
# 27737        9962           有益  2016         79922.0             12713.0
# 27738        9962           有益  2017         71770.0             12014.0
# 27739        9962           有益  2018        116210.0             22031.0
# 27740        9962           有益  2019         14515.0              3100.0
# 27741        9962           有益  2020          1011.0              -181.0
#
#        cont_oper_IL  discont_oper_IL     profit  other_comprehensive_income  \
# ...
