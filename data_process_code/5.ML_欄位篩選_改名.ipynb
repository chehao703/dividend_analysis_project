# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Student\Desktop\損益表_資產負債合併_除權息\保險_2001_2020.csv')
df
# Out:
#        公司   簡稱     年   月  季別       營業收入       營業成本     營業費用  營業利益（損失）  \
# 0    2816  旺旺保  2001  12   4   10912162    9531095  1192209    188858
# 1    2816  旺旺保  2002  12   4   10351622    8658954  1400581    292087
# 2    2816  旺旺保  2003  12   4   14915625   12793896  1858065    263664
# 3    2816  旺旺保  2004  12   4   16406672   14074793  2041429    290450
# 4    2816  旺旺保  2005  12   4   17502403   15619784  2009523   -126904
# ..    ...  ...   ...  ..  ..        ...        ...      ...       ...
# 134  2867  三商壽  2016  12   4  174076303  165560096  5505682   3010525
# 135  2867  三商壽  2017  12   4  184987213  176620810  4970753   3395650
# 136  2867  三商壽  2018  12   4  167844489  164889627  4613142  -1658280
# 137  2867  三商壽  2019  12   4  179022429  169411922  4807540   4802967
# 138  2867  三商壽  2020  12   4  157231964  151057815  4611774   1562375
#
#      營業外收入及支出  ...  最近一次_股息發放日  Q1_股息發放日  Q2_股息發放日  Q3_股息發放日  Q4_股息發放日  \
# ...

# %%
data = df.iloc[:,lambda x :[0,1,2,10,11,12,13,15,16,18,19,20,21,22,23,24,25,38,56,57,58,59,60,61,62,63,65,66,68,67,69,74,80,83]]
data
# Out:
#        公司   簡稱     年     稅前淨利    所得稅費用  繼續營業單位損益  停業單位損益      合併總損益  \
# 0    2816  旺旺保  2001   292744    40842    251902       0   251902.0
# 1    2816  旺旺保  2002   316197   110789    205408       0   205408.0
# 2    2816  旺旺保  2003   339283    93138    246145       0   246145.0
# 3    2816  旺旺保  2004   330227    70881    259346       0   259346.0
# 4    2816  旺旺保  2005   -22335    -7983    -14352       0   -14352.0
# ..    ...  ...   ...      ...      ...       ...     ...        ...
# 134  2867  三商壽  2016  2893025   -67972   2960997       0  2960997.0
# 135  2867  三商壽  2017  3341161   156209   3184952       0  3184952.0
# 136  2867  三商壽  2018 -1533678 -1221265   -312413       0  -312413.0
# 137  2867  三商壽  2019  4934190   -77322   5011512       0  5011512.0
# 138  2867  三商壽  2020  1740311   295773   1444538       0  1444538.0
#
#      其他綜合損益（稅後）      本期綜合損益  ...  母公司股東權益合計  共同控制下前手權益  非控制權益    股東權益總額  \
# 0           NaN         NaN  ...  5345483.0        0.0    0.0   5345483
# ...

# %%
data1 = df.iloc[:,13:]
data1
# Out:
#      停業單位損益  合併前非屬共同控制股權損益      合併總損益  其他綜合損益（稅後）    合併前非屬共同控制股權綜合損益淨額－OCI  \
# 0         0            0.0   251902.0         NaN                      NaN
# 1         0            0.0   205408.0         NaN                      NaN
# 2         0            0.0   246145.0         NaN                      NaN
# 3         0            0.0   259346.0         NaN                      NaN
# 4         0            0.0   -14352.0         NaN                      NaN
# ..      ...            ...        ...         ...                      ...
# 134       0            0.0  2960997.0   1176876.0                      0.0
# 135       0            0.0  3184952.0   3426501.0                      0.0
# 136       0            0.0  -312413.0 -15272084.0                      0.0
# 137       0            0.0  5011512.0   8685008.0                      0.0
# 138       0            0.0  1444538.0  -2967401.0                      0.0
#
# ...

# %%
data.shape
# Out:
# (139, 34)

# %%
data.to_csv(r'C:\Users\Student\Desktop\ML_欄位\保險_2001_2020.csv', index=False)
